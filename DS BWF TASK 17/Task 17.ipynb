# %%
import matplotlib.pyplot as plt
import numpy as np

x =np.linspace(0, 10, 100)
y = np.sin(x)
z = np.random.rand(100)

categories = ['A', 'B','C']
values = [10, 15, 7]

fig, axs = plt.subplots(2,2, figsize=(10, 10))

axs[0, 0].plot(x, y, label='sin(x)')
axs[0, 0].set_title('Line Plot')
axs[0, 0].set_xlabel('x')
axs[0, 0].set_ylabel('sin(x)')
axs[0, 0].legend()

axs[0,1].scatter(x, z, color='r', label='random points')
axs[0, 1].set_title('Scatter Plot')
axs[0, 1].set_xlabel('x')
axs[0, 1].set_ylabel('random values')
axs[0, 1].legend()

axs[1, 0].scatter(categories, values, color=['blue','green','red'])
axs[1, 0].set_title('Bar Plot')
axs[1, 0].set_xlabel('Category')
axs[1, 0].set_ylabel('Value')

axs[1, 1].hist(z, bins=10, color='purple')
axs[1, 1].set_title('Histogram')
axs[1, 1].set_xlabel('Value')
axs[1, 1].set_ylabel('Frequency')

plt.tight_layout()
plt.show()

# %%
data1= np.random.normal(0, 1, 1000)
data2=np.random.normal(5,1,1000)

plt.hist(data1, bins=20, alpha=0.5, label='Data 1')
plt.hist(data2,bins=20,alpha=0.5,label='Data 2')
plt.title('Histogram Comparison')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.legend()
plt.show()

plt.hist(data1, bins=20, alpha=0.5, density=True, label='Data 1')
plt.hist(data2, bins=20,alpha=0.5,density=True,label='Data 2')
plt.title('Normalized Histogram Comparison')
plt.xlabel('Value')
plt.ylabel('Density')
plt.legend()
plt.show()

# %%
data1 = np.random.normal(0, 1, 100)
data2 = np.random.normal(5, 1,100)
data3 = np.random.normal(10,1,100)

data = [data1, data2, data3]
plt.boxplot(data, patch_artist=True, notch=True,boxprops=dict(facecolor='lightblue',color='blue'),
capprops=dict(color='blue'),
whiskerprops=dict(color='blue'),
flierprops=dict(marker='o', color='red', alpha=0.5),
medianprops=dict(color='red'))

plt.title('Box Plot Comparison')
plt.xlabel('Data Set')
plt.ylabel('Value')
plt.xticks([1, 2, 3], ['Data 1','Data 2','Data 3'])
plt.show()
